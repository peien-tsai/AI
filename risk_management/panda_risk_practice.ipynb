# %%
import numpy as np
weight_array = np.array([0.15,0.2,0.25,0.4])
return_array = np.array([[0.003731,0.021066,-0.004854,0.006098,-0.00606],[-0.001838,0.001842,-0.016544,-0.003738,0.003752],[-0.003087,-0.000344,-0.033391,0.007123,0.004597],[-0.024112,0.011704,-0.029563,-0.01457,0.016129]])

# %%
import pandas as pd

# %%
return_series1 = pd.Series([0.003731,-0.001838,-0.003087,-0.024112],index = ['中國石油','工商銀行','上汽集團','寶鋼股份'])
return_series1
# Out:
# 中國石油    0.003731
# 工商銀行   -0.001838
# 上汽集團   -0.003087
# 寶鋼股份   -0.024112
# dtype: float64

# %%
return_series2 = pd.Series(return_array[:,0],index = ['中國石油','工商銀行','上汽集團','寶鋼股份'])
return_series2
# Out:
# 中國石油    0.003731
# 工商銀行   -0.001838
# 上汽集團   -0.003087
# 寶鋼股份   -0.024112
# dtype: float64

# %% [markdown]
# 資料框(DataFrame)

# %%
date = ['2018-09-03','2018-09-04','2018-09-05','2018-09-06','2018-09-07']
stock = ['中國石油','工商銀行','上汽集團','寶鋼股份']

# %%
return_dataframe = pd.DataFrame(data = return_array.T,index = date,columns=stock)
return_dataframe
# Out:
#                 中國石油      工商銀行      上汽集團      寶鋼股份
# 2018-09-03  0.003731 -0.001838 -0.003087 -0.024112
# 2018-09-04  0.021066  0.001842 -0.000344  0.011704
# 2018-09-05 -0.004854 -0.016544 -0.033391 -0.029563
# 2018-09-06  0.006098 -0.003738  0.007123 -0.014570
# 2018-09-07 -0.006060  0.003752  0.004597  0.016129

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#存檔
from openpyxl import *
return_dataframe.to_excel('D:/return.xlsx') #excel
return_dataframe.to_csv('D:/return.csv') #csv
return_dataframe.to_csv('D:/return.txt') #txt

# %%
#讀取檔案
# read_table('檔案路徑',index_col=0代表將第一列作為索引,delimiter='指定分隔符號')
# read_excel('檔案路徑',sheetname='工作表名稱',index_col=0代表將第一列作為索引,header=0行title)
# read_csv('檔案路徑或網址',sep='指定分隔符號',delimiter='備選分隔符號'(若有用這個sep會故障),index_col=0代表將第一列作為索引,header=0行title)

csv_test = pd.read_csv('D:/return.csv',delimiter=',',index_col=0,header=0)
csv_test
# Out:
#                 中國石油      工商銀行      上汽集團      寶鋼股份
# 2018-09-03  0.003731 -0.001838 -0.003087 -0.024112
# 2018-09-04  0.021066  0.001842 -0.000344  0.011704
# 2018-09-05 -0.004854 -0.016544 -0.033391 -0.029563
# 2018-09-06  0.006098 -0.003738  0.007123 -0.014570
# 2018-09-07 -0.006060  0.003752  0.004597  0.016129

# %% [markdown]
# # Dataframe的視覺化 plot

# %%
taiwan_weighted_index = pd.read_csv('D:/taiwan_weighted_index.csv',delimiter=',',index_col=0,header=0)
taiwan_weighted_index.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2020-01-02  12026.500000  12110.740234  12026.230469  12100.480469
# 2020-01-03  12167.440430  12197.639648  12023.599609  12110.429688
# 2020-01-06  12035.709961  12040.080078  11953.360352  11953.360352
# 2020-01-07  11961.969727  11986.030273  11822.400391  11880.320313
# 2020-01-08  11818.759766  11899.669922  11777.450195  11817.099609
#
#                Adj Close   Volume
# Date
# 2020-01-02  12100.480469  2023800
# 2020-01-03  12110.429688  2572900
# 2020-01-06  11953.360352  2345200
# 2020-01-07  11880.320313  2338400
# 2020-01-08  11817.099609  2428800

# %%
taiwan_weighted_index = taiwan_weighted_index.drop(['Adj Close', 'Volume'], axis=1)

# %%
taiwan_weighted_index.to_excel('D:/taiwan_weighted_index.xlsx')
taiwan_weighted_index = pd.read_excel('D:/taiwan_weighted_index.xlsx',sheet_name='Sheet1',header=0,index_col=0)

# %% [markdown]
# ●中文字型的視覺化

# %%
from pylab import mpl 
mpl.rcParams['font.sans-serif'] = ['SimHei'] #以黑體的字型顯示中文
mpl.rcParams['axes.unicode_minus'] = False #解決儲存的影像中，'-'為方塊的問題
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
taiwan_weighted_index.plot(kind='line',subplots=True,sharex=True,sharey=True,layout=(2,2),figsize=(10,8),title=u'2020台灣加權股價指數走勢圖',grid=True,fontsize=13)
# Out:
# array([[<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>],
#        [<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>]],
#       dtype=object)

# %% [markdown]
# # DataFrame的操作

# %% [markdown]
# ●基本性質

# %%
taiwan_weighted_index.index
# Out:
# Index(['2020-01-02', '2020-01-03', '2020-01-06', '2020-01-07', '2020-01-08',
#        '2020-01-09', '2020-01-10', '2020-01-13', '2020-01-14', '2020-01-15',
#        ...
#        '2020-11-09', '2020-11-10', '2020-11-11', '2020-11-12', '2020-11-13',
#        '2020-11-16', '2020-11-17', '2020-11-18', '2020-11-19', '2020-11-20'],
#       dtype='object', name='Date', length=216)

# %%
taiwan_weighted_index.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close'], dtype='object')

# %%
taiwan_weighted_index.describe() #檢視樣本數、平均、變異、最大小值、分位數
# Out:
#                Open          High           Low         Close
# count    216.000000    216.000000    216.000000    216.000000
# mean   11794.578903  11863.659781  11719.787272  11791.932124
# std     1055.361823   1041.463643   1071.602661   1055.588488
# min     8816.860352   9029.519531   8523.629883   8681.339844
# 25%    11011.502686  11083.077637  10939.937256  11007.117187
# 50%    11937.535157  11989.290039  11873.680176  11931.260254
# 75%    12693.260254  12765.929932  12627.340088  12700.445068
# max    13775.259766  13785.919922  13700.040039  13773.290039

# %%
taiwan_weighted_index.shape
# Out:
# (216, 4)

# %% [markdown]
# ●索引及截取 loc,iloc(index),ix(index或索引值名稱都可)

# %%
taiwan_weighted_index[:3] #截取前三行
# Out:
#                     Open          High           Low         Close
# Date
# 2020-01-02  12026.500000  12110.740234  12026.230469  12100.480469
# 2020-01-03  12167.440430  12197.639648  12023.599609  12110.429688
# 2020-01-06  12035.709961  12040.080078  11953.360352  11953.360352

# %%
taiwan_weighted_index[2:8] #截取前三行
# Out:
#                     Open          High           Low         Close
# Date
# 2020-01-06  12035.709961  12040.080078  11953.360352  11953.360352
# 2020-01-07  11961.969727  11986.030273  11822.400391  11880.320313
# 2020-01-08  11818.759766  11899.669922  11777.450195  11817.099609
# 2020-01-09  11889.459961  11992.549805  11889.459961  11970.629883
# 2020-01-10  12009.269531  12038.209961  11959.059570  12024.650391
# 2020-01-13  12069.610352  12113.419922  12037.240234  12113.419922

# %%
taiwan_weighted_index[taiwan_weighted_index['Close']<11000] #找出收盤點超過11000
# Out:
#                     Open          High           Low         Close
# Date
# 2020-03-09  11221.759766  11221.759766  10977.639648  10977.639648
# 2020-03-11  11022.820313  11088.230469  10885.910156  10893.750000
# 2020-03-12  10845.389648  10845.389648  10359.669922  10422.320313
# 2020-03-13  10091.030273  10171.200195   9636.150391  10128.870117
# 2020-03-16  10069.419922  10130.799805   9717.769531   9717.769531
# 2020-03-17   9538.639648   9677.070313   9371.349609   9439.629883
# 2020-03-18   9453.980469   9509.610352   9218.669922   9218.669922
# 2020-03-19   9085.280273   9085.280273   8523.629883   8681.339844
# 2020-03-20   8816.860352   9264.419922   8816.860352   9234.089844
# 2020-03-23   9025.549805   9029.519531   8750.139648   8890.030273
# 2020-03-24   9083.780273   9415.639648   9083.780273   9285.620117
# 2020-03-25   9426.429688   9722.370117   9426.429688   9644.750000
# 2020-03-26   9667.139648   9739.730469   9565.019531   9736.360352
# ...

# %%
taiwan_weighted_index[(taiwan_weighted_index['Close']<11000) & (taiwan_weighted_index['Open']>11000)]
# Out:
#                     Open          High           Low         Close
# Date
# 2020-03-09  11221.759766  11221.759766  10977.639648  10977.639648
# 2020-03-11  11022.820313  11088.230469  10885.910156  10893.750000
# 2020-05-28  11040.620117  11087.530273  10915.299805  10944.190430

# %%
#排序sort_index
taiwan_weighted_index.sort_index(axis=0,ascending=False)
# Out:
#                     Open          High           Low         Close
# Date
# 2020-11-20  13702.589844  13726.219727  13666.070313  13716.440430
# 2020-11-19  13775.259766  13785.919922  13700.040039  13722.429688
# 2020-11-18  13628.419922  13773.290039  13608.719727  13773.290039
# 2020-11-17  13723.769531  13780.120117  13593.009766  13593.009766
# 2020-11-16  13356.740234  13551.830078  13356.740234  13551.830078
# ...                  ...           ...           ...           ...
# 2020-01-08  11818.759766  11899.669922  11777.450195  11817.099609
# 2020-01-07  11961.969727  11986.030273  11822.400391  11880.320313
# 2020-01-06  12035.709961  12040.080078  11953.360352  11953.360352
# 2020-01-03  12167.440430  12197.639648  12023.599609  12110.429688
# 2020-01-02  12026.500000  12110.740234  12026.230469  12100.480469
#
# [216 rows x 4 columns]

# %%
#指定欄位名稱的數值排序
taiwan_weighted_index.sort_values(by='Close',ascending=False)
# Out:
#                     Open          High           Low         Close
# Date
# 2020-11-18  13628.419922  13773.290039  13608.719727  13773.290039
# 2020-11-19  13775.259766  13785.919922  13700.040039  13722.429688
# 2020-11-20  13702.589844  13726.219727  13666.070313  13716.440430
# 2020-11-17  13723.769531  13780.120117  13593.009766  13593.009766
# 2020-11-16  13356.740234  13551.830078  13356.740234  13551.830078
# ...                  ...           ...           ...           ...
# 2020-03-24   9083.780273   9415.639648   9083.780273   9285.620117
# 2020-03-20   8816.860352   9264.419922   8816.860352   9234.089844
# 2020-03-18   9453.980469   9509.610352   9218.669922   9218.669922
# 2020-03-23   9025.549805   9029.519531   8750.139648   8890.030273
# 2020-03-19   9085.280273   9085.280273   8523.629883   8681.339844
#
# [216 rows x 4 columns]

# %% [markdown]
# ●欄位名稱修改

# %%
columnschange=taiwan_weighted_index.rename(columns={'Open':'開盤價'})
columnschange
# Out:
#                      開盤價          High           Low         Close
# Date
# 2020-01-02  12026.500000  12110.740234  12026.230469  12100.480469
# 2020-01-03  12167.440430  12197.639648  12023.599609  12110.429688
# 2020-01-06  12035.709961  12040.080078  11953.360352  11953.360352
# 2020-01-07  11961.969727  11986.030273  11822.400391  11880.320313
# 2020-01-08  11818.759766  11899.669922  11777.450195  11817.099609
# ...                  ...           ...           ...           ...
# 2020-11-16  13356.740234  13551.830078  13356.740234  13551.830078
# 2020-11-17  13723.769531  13780.120117  13593.009766  13593.009766
# 2020-11-18  13628.419922  13773.290039  13608.719727  13773.290039
# 2020-11-19  13775.259766  13785.919922  13700.040039  13722.429688
# 2020-11-20  13702.589844  13726.219727  13666.070313  13716.440430
#
# [216 rows x 4 columns]

# %% [markdown]
# ●遺缺值處理

# %%
df_date = pd.date_range('2020-01-01','2020-11-20')  
TSMC = taiwan_weighted_index.reindex(df_date)

# %%
#把index(日期）變成datetime型別
taiwan_weighted_index.index = pd.to_datetime(taiwan_weighted_index.index)

# %%
TSMC
# Out:
#                     Open          High           Low         Close
# 2020-01-01           NaN           NaN           NaN           NaN
# 2020-01-02  12026.500000  12110.740234  12026.230469  12100.480469
# 2020-01-03  12167.440430  12197.639648  12023.599609  12110.429688
# 2020-01-04           NaN           NaN           NaN           NaN
# 2020-01-05           NaN           NaN           NaN           NaN
# ...                  ...           ...           ...           ...
# 2020-11-16  13356.740234  13551.830078  13356.740234  13551.830078
# 2020-11-17  13723.769531  13780.120117  13593.009766  13593.009766
# 2020-11-18  13628.419922  13773.290039  13608.719727  13773.290039
# 2020-11-19  13775.259766  13785.919922  13700.040039  13722.429688
# 2020-11-20  13702.589844  13726.219727  13666.070313  13716.440430
#
# [325 rows x 4 columns]

# %% [markdown]
# ●遺漏值-刪除法

# %%
TSMC_dropna = TSMC.dropna()
TSMC_dropna
# Out:
#                     Open          High           Low         Close
# 2020-01-02  12026.500000  12110.740234  12026.230469  12100.480469
# 2020-01-03  12167.440430  12197.639648  12023.599609  12110.429688
# 2020-01-06  12035.709961  12040.080078  11953.360352  11953.360352
# 2020-01-07  11961.969727  11986.030273  11822.400391  11880.320313
# 2020-01-08  11818.759766  11899.669922  11777.450195  11817.099609
# ...                  ...           ...           ...           ...
# 2020-11-16  13356.740234  13551.830078  13356.740234  13551.830078
# 2020-11-17  13723.769531  13780.120117  13593.009766  13593.009766
# 2020-11-18  13628.419922  13773.290039  13608.719727  13773.290039
# 2020-11-19  13775.259766  13785.919922  13700.040039  13722.429688
# 2020-11-20  13702.589844  13726.219727  13666.070313  13716.440430
#
# [216 rows x 4 columns]

# %% [markdown]
# ●補齊法(用0補)

# %%
TSMC_fillna = TSMC.fillna(value=0)
TSMC_fillna
# Out:
#                     Open          High           Low         Close
# 2020-01-01      0.000000      0.000000      0.000000      0.000000
# 2020-01-02  12026.500000  12110.740234  12026.230469  12100.480469
# 2020-01-03  12167.440430  12197.639648  12023.599609  12110.429688
# 2020-01-04      0.000000      0.000000      0.000000      0.000000
# 2020-01-05      0.000000      0.000000      0.000000      0.000000
# ...                  ...           ...           ...           ...
# 2020-11-16  13356.740234  13551.830078  13356.740234  13551.830078
# 2020-11-17  13723.769531  13780.120117  13593.009766  13593.009766
# 2020-11-18  13628.419922  13773.290039  13608.719727  13773.290039
# 2020-11-19  13775.259766  13785.919922  13700.040039  13722.429688
# 2020-11-20  13702.589844  13726.219727  13666.070313  13716.440430
#
# [325 rows x 4 columns]

# %% [markdown]
# ●向前填充(遺漏值的前一個值補)

# %%
TSMC_ffill = TSMC.fillna(method='ffill')
TSMC_ffill
# Out:
#                     Open          High           Low         Close
# 2020-01-01           NaN           NaN           NaN           NaN
# 2020-01-02  12026.500000  12110.740234  12026.230469  12100.480469
# 2020-01-03  12167.440430  12197.639648  12023.599609  12110.429688
# 2020-01-04  12167.440430  12197.639648  12023.599609  12110.429688
# 2020-01-05  12167.440430  12197.639648  12023.599609  12110.429688
# ...                  ...           ...           ...           ...
# 2020-11-16  13356.740234  13551.830078  13356.740234  13551.830078
# 2020-11-17  13723.769531  13780.120117  13593.009766  13593.009766
# 2020-11-18  13628.419922  13773.290039  13608.719727  13773.290039
# 2020-11-19  13775.259766  13785.919922  13700.040039  13722.429688
# 2020-11-20  13702.589844  13726.219727  13666.070313  13716.440430
#
# [325 rows x 4 columns]

# %% [markdown]
# ●向後填充(遺漏值的後一個值補)

# %%
TSMC_bfill = TSMC.fillna(method='bfill')
TSMC_bfill
# Out:
#                     Open          High           Low         Close
# 2020-01-01  12026.500000  12110.740234  12026.230469  12100.480469
# 2020-01-02  12026.500000  12110.740234  12026.230469  12100.480469
# 2020-01-03  12167.440430  12197.639648  12023.599609  12110.429688
# 2020-01-04  12035.709961  12040.080078  11953.360352  11953.360352
# 2020-01-05  12035.709961  12040.080078  11953.360352  11953.360352
# ...                  ...           ...           ...           ...
# 2020-11-16  13356.740234  13551.830078  13356.740234  13551.830078
# 2020-11-17  13723.769531  13780.120117  13593.009766  13593.009766
# 2020-11-18  13628.419922  13773.290039  13608.719727  13773.290039
# 2020-11-19  13775.259766  13785.919922  13700.040039  13722.429688
# 2020-11-20  13702.589844  13726.219727  13666.070313  13716.440430
#
# [325 rows x 4 columns]

# %% [markdown]
# ●DataFrame的連結(join,merge,concat)

# %%
#pd.concat(['資料1','資料2'],axis=1) #axis=0按行連接(變長) axis=1(變寬)
#pd.merge(left=資料1,right=資料2,left_index=True,rightt_index=True) 
#資料1.join(資料2,on='按照哪個索引')

# %% [markdown]
# ●靜態的統計函數

# %%
taiwan_weighted_index.idxmax()
# Out:
# Open    2020-11-19
# High    2020-11-19
# Low     2020-11-19
# Close   2020-11-18
# dtype: datetime64[ns]

# %%
taiwan_weighted_index.idxmin()
# Out:
# Open    2020-03-20
# High    2020-03-23
# Low     2020-03-19
# Close   2020-03-19
# dtype: datetime64[ns]

# %%
taiwan_weighted_index.kurt() #峰度
# Out:
# Open    -0.263699
# High    -0.366215
# Low     -0.106950
# Close   -0.217314
# dtype: float64

# %% [markdown]
# ●移動時窗

# %%
#移動平均
taiwan_weighted_index_open = taiwan_weighted_index['Open'].rolling(window=20).mean() #開盤價20日移動平均
taiwan_weighted_index_open
# Out:
# Date
# 2020-01-02             NaN
# 2020-01-03             NaN
# 2020-01-06             NaN
# 2020-01-07             NaN
# 2020-01-08             NaN
#                   ...
# 2020-11-16    12924.153027
# 2020-11-17    12965.841992
# 2020-11-18    13002.768994
# 2020-11-19    13048.783496
# 2020-11-20    13086.656983
# Name: Open, Length: 216, dtype: float64

# %%
#將序列變成dataframe
taiwan_weighted_index_open = taiwan_weighted_index_open.to_frame()
taiwan_weighted_index_open
# Out:
#                     Open
# Date
# 2020-01-02           NaN
# 2020-01-03           NaN
# 2020-01-06           NaN
# 2020-01-07           NaN
# 2020-01-08           NaN
# ...                  ...
# 2020-11-16  12924.153027
# 2020-11-17  12965.841992
# 2020-11-18  13002.768994
# 2020-11-19  13048.783496
# 2020-11-20  13086.656983
#
# [216 rows x 1 columns]

# %%
taiwan_weighted_index_open =taiwan_weighted_index_open.rename(columns={'Open':'20日平均開盤'})
taiwan_weighted_index_open
# Out:
#                  20日平均開盤
# Date
# 2020-01-02           NaN
# 2020-01-03           NaN
# 2020-01-06           NaN
# 2020-01-07           NaN
# 2020-01-08           NaN
# ...                  ...
# 2020-11-16  12924.153027
# 2020-11-17  12965.841992
# 2020-11-18  13002.768994
# 2020-11-19  13048.783496
# 2020-11-20  13086.656983
#
# [216 rows x 1 columns]

# %%
TSMC_Open = taiwan_weighted_index['Open'].to_frame()

# %%
TSMC_Open_new = pd.concat([TSMC_Open,taiwan_weighted_index_open],axis=1)
TSMC_Open_new
# Out:
#                     Open       20日平均開盤
# Date
# 2020-01-02  12026.500000           NaN
# 2020-01-03  12167.440430           NaN
# 2020-01-06  12035.709961           NaN
# 2020-01-07  11961.969727           NaN
# 2020-01-08  11818.759766           NaN
# ...                  ...           ...
# 2020-11-16  13356.740234  12924.153027
# 2020-11-17  13723.769531  12965.841992
# 2020-11-18  13628.419922  13002.768994
# 2020-11-19  13775.259766  13048.783496
# 2020-11-20  13702.589844  13086.656983
#
# [216 rows x 2 columns]

# %%
TSMC_Open_new.plot(figsize=(10,7),title=u'202001-202011加權股價指數走勢',grid=True,fontsize=12)
# Out:
# <AxesSubplot:title={'center':'202001-202011加權股價指數走勢'}, xlabel='Date'>
